# %%
#Implement exploratory data analysis and gain an understanding of the data set and its features.

# %%
import pandas as pd

# Load the data from the CSV file
data = pd.read_csv("slighted.csv")

# Print the first few rows
print(data.head())
# Out:
#         Timestamp 1. What is your biggest reason for learning to code?  \
# 0  07/01/21 10:10                       To succeed in current career
# 1  07/01/21 10:31                                  To change careers
# 2  07/01/21 10:42                                  To change careers
# 3  07/01/21 11:06                                         As a hobby
# 4  07/01/21 11:14                         To start your first career
#
#   2. What methods have you used to learn about coding? Please select all that apply.  \
# 0  Online resources, Books, In-person bootcamps, ...
# 1          Online resources, Books, Online bootcamps
# 2  Online resources, Books, Hackathons, Meetup.co...
# 3                            Online resources, Books
# 4          Online resources, Books, Online bootcamps
#
#   3. Which online learning resources have you found helpful? Please select all that apply.  \
# 0  freeCodeCamp, Mozilla Developer Network (MDN),...
# 1  freeCodeCamp, Mozilla Developer Network (MDN),...
# 2  freeCodeCamp, Mozilla Developer Network (MDN),...
# 3  freeCodeCamp, Mozilla Developer Network (MDN),...
# 4      freeCodeCamp, Stack Overflow, Coursera, Udemy
#
#   4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.  \
# 0          conferences, workshops, Meetup.com events
# 1  I haven't attended any in-person coding-relate...
# 2                                  Meetup.com events
# 3  I haven't attended any in-person coding-relate...
# 4  I haven't attended any in-person coding-relate...
#
#   5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.  \
# 0                                      The Changelog
# 1                 The Changelog, Code Newbie Podcast
# 2                 I haven't listened to any podcasts
# 3               Darknet Diaries, Real Python Podcast
# 4                                  Talk Python to Me
#
#   6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.  \
# 0                              CS Dojo, freeCodeCamp
# 1  Adrian Twarog, Code with Ania KubÃ³w, Coder Co...
# 2  AmigosCode, Dev Ed, freeCodeCamp, Kevin Powell...
# 3                       freeCodeCamp, Traversy Media
# 4        freeCodeCamp, The Net Ninja, Traversy Media
#
#    7. About how many hours do you spend learning each week?  \
# 0                                                4.0
# 1                                               10.0
# 2                                               30.0
# 3                                                NaN
# 4                                                2.0
#
#    8. About how many months have you been programming?  \
# 0                                                120
# 1                                                  6
# 2                                                 48
# 3                                                 36
# 4                                                 24
#
#    9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?  \
# 0                                                NaN
# 1                                               30.0
# 2                                              300.0
# 3                                                0.0
# 4                                             5000.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Job security]  \
# 0                                 Somewhat satisfied
# 1                                  Very dissatisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                              Somewhat dissatisfied
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Work-life balance]  \
# 0                              Somewhat dissatisfied
# 1                                 Somewhat satisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                                 Somewhat satisfied
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Professional growth or leadership opportunities]  \
# 0                                      I do not know
# 1                              Somewhat dissatisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                              Somewhat dissatisfied
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Workplace/company culture]  \
# 0                                 Somewhat satisfied
# 1                              Somewhat dissatisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                                 Somewhat satisfied
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Diverse and inclusive work environment]  \
# 0                                 Somewhat satisfied
# 1                                 Somewhat satisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                              Somewhat dissatisfied
#
#   45. Please tell us how satisfied you are with each of these following aspects of your present job [Weekly workload]  \
# 0                                  Very dissatisfied
# 1                                 Somewhat satisfied
# 2                                     Not Applicable
# 3                                                NaN
# 4                              Somewhat dissatisfied
#
#   46. About how many minutes does it take you to get to work each day?  \
# 0                                   I work from home
# 1                                   15 to 29 minutes
# 2                                   I am not working
# 3                                   I am not working
# 4                                   45 to 60 minutes
#
#   47. Have you served in your country's military before?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   48. Do you currently receive disability benefits from your government?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   49. Do you have high speed internet at your home?
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                                No
# 4                                               Yes
#
# [5 rows x 63 columns]

# %%
print(f"The dataset has {data.shape[0]} rows and {data.shape[1]} columns.")
data.info()
data.describe()
data['1. What is your biggest reason for learning to code?'].value_counts()
print(data.isnull().sum())
# Out:
# The dataset has 10 rows and 63 columns.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                   10 non-null     object
#  1   1. What is your biggest reason for learning to code?                                                                                                                        10 non-null     object
#  2   2. What methods have you used to learn about coding? Please select all that apply.                                                                                          10 non-null     object
#  3   3. Which online learning resources have you found helpful? Please select all that apply.                                                                                    10 non-null     object
#  4   4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.                                            10 non-null     object
#  5   5. If you have listened to coding-related podcasts before, which ones have you found helpful? Please select all that apply.                                                 10 non-null     object
#  6   6. If you have watched coding-related YouTube videos before, which channels have you found helpful? Please select all that apply.                                           10 non-null     object
#  7   7. About how many hours do you spend learning each week?                                                                                                                    9 non-null      float64
#  8   8. About how many months have you been programming?                                                                                                                         10 non-null     int64
#  9   9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?                                                           9 non-null      float64
#  10  10. Are you already employed in a software development job?                                                                                                                 10 non-null     object
#  11  11. If you are already employed as a developer, is this your first software development job?                                                                                10 non-null     object
#  12  12. If you are NOT already a developer, are you interested in a software development career?                                                                                9 non-null      object
#  13  13. If you are interested in a software development career, would you prefer to...                                                                                          9 non-null      object
#  14  14. Which of these careers are you interested in?                                                                                                                           10 non-null     object
#  15  15. When do you plan to start applying for developer jobs?                                                                                                                  10 non-null     object
#  16  16. About how much money do you expect to earn per year at your first developer job (in US Dollars)?                                                                        8 non-null      object
#  17  17. Please select up to 3 reasons why you are interested in a software development career                                                                                   10 non-null     object
#  18  18. After the pandemic, how many days would you ideally like to work from home versus in an office each week?                                                               10 non-null     object
#  19  19. Are you willing to relocate for a job?                                                                                                                                  10 non-null     object
#  20  20. Regarding employment status, are you currently....                                                                                                                      10 non-null     object
#  21  21. If you are currently working, which field do you work in?                                                                                                               10 non-null     object
#  22  22. About how much money did you earn last year from any job or employment (in US Dollars)?                                                                                 7 non-null      object
#  23  23. How old are you?                                                                                                                                                        9 non-null      float64
#  24  24. Which of the following best represents how you think of yourself?                                                                                                       10 non-null     object
#  25  25. With which of these groups do you primarily identify?                                                                                                                   9 non-null      object
#  26  26. Which part of the world do you live in?                                                                                                                                 10 non-null     object
#  27  27. If you are living in the US, which state do you currently live in?                                                                                                      6 non-null      object
#  28  28. About how many people live in your city?                                                                                                                                10 non-null     object
#  29  29. Is your country of citizenship different from the country where you live?                                                                                               10 non-null     object
#  30  30. Are you an ethnic minority in your country?                                                                                                                             8 non-null      object
#  31  31. Is English your second language?                                                                                                                                        10 non-null     object
#  32  32. What is the highest degree or level of school you have completed?                                                                                                       10 non-null     object
#  33  33. If you attended a university, what did you study?                                                                                                                       10 non-null     object
#  34  34. Are you currently a student attending or enrolled in regular school, that is in an elementary school, a middle school, a high school, a college, or a graduate school?  10 non-null     object
#  35  35. What's your marital status?                                                                                                                                             9 non-null      object
#  36  36. How many children do you have? By children, we mean any biological, step, or adopted children.                                                                          9 non-null      float64
#  37  37. Do you financially support any dependents, older relatives or relatives with disabilities?                                                                              9 non-null      object
#  38  38. Do you think you have enough savings to survive for 3 months with no income?                                                                                            10 non-null     object
#  39  39. How much debt does your household have? [Car loans]                                                                                                                     2 non-null      object
#  40  39. How much debt does your household have? [Credit Cards]                                                                                                                  3 non-null      object
#  41  39. How much debt does your household have? [Medical Loans]                                                                                                                 0 non-null      float64
#  42  39. How much debt does your household have? [Mortgages]                                                                                                                     3 non-null      object
#  43  39. How much debt does your household have? [Payday Loans]                                                                                                                  1 non-null      object
#  44  39. How much debt does your household have? [Student Loans]                                                                                                                 3 non-null      object
#  45  39. How much debt does your household have? [Other]                                                                                                                         0 non-null      float64
#  46  40. How long have you been working in your current job?                                                                                                                     10 non-null     object
#  47  41. Before you got your last job, how many months did you spend looking for a job?                                                                                          9 non-null      float64
#  48  42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?                                        8 non-null      float64
#  49  43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have?               8 non-null      float64
#  50  44. Do you consider yourself under-employed? (Under-employment means working a job that is below your education level.)                                                     10 non-null     object
#  51  45. Please tell us how satisfied you are with each of these following aspects of your present job [Earnings]                                                                9 non-null      object
#  52  45. Please tell us how satisfied you are with each of these following aspects of your present job [Benefits]                                                                9 non-null      object
#  53  45. Please tell us how satisfied you are with each of these following aspects of your present job [Job security]                                                            9 non-null      object
#  54  45. Please tell us how satisfied you are with each of these following aspects of your present job [Work-life balance]                                                       9 non-null      object
#  55  45. Please tell us how satisfied you are with each of these following aspects of your present job [Professional growth or leadership opportunities]                         9 non-null      object
#  56  45. Please tell us how satisfied you are with each of these following aspects of your present job [Workplace/company culture]                                               9 non-null      object
#  57  45. Please tell us how satisfied you are with each of these following aspects of your present job [Diverse and inclusive work environment]                                  9 non-null      object
#  58  45. Please tell us how satisfied you are with each of these following aspects of your present job [Weekly workload]                                                         9 non-null      object
#  59  46. About how many minutes does it take you to get to work each day?                                                                                                        10 non-null     object
#  60  47. Have you served in your country's military before?                                                                                                                      10 non-null     object
#  61  48. Do you currently receive disability benefits from your government?                                                                                                      10 non-null     object
#  62  49. Do you have high speed internet at your home?                                                                                                                           10 non-null     object
# dtypes: float64(9), int64(1), object(53)
# memory usage: 5.1+ KB
# Timestamp                                                                                                                           0
# 1. What is your biggest reason for learning to code?                                                                                0
# 2. What methods have you used to learn about coding? Please select all that apply.                                                  0
# 3. Which online learning resources have you found helpful? Please select all that apply.                                            0
# 4. If you have attended in-person coding-related events before, which ones have you found helpful? Please select all that apply.    0
#                                                                                                                                    ..
# 45. Please tell us how satisfied you are with each of these following aspects of your present job [Weekly workload]                 1
# 46. About how many minutes does it take you to get to work each day?                                                                0
# 47. Have you served in your country's military before?                                                                              0
# 48. Do you currently receive disability benefits from your government?                                                              0
# 49. Do you have high speed internet at your home?                                                                                   0
# Length: 63, dtype: int64

# %%
print("Unique values in '1. What is your biggest reason for learning to code?'")
print(data['1. What is your biggest reason for learning to code?'].value_counts())
print("\nUnique values in '14. Which of these careers are you interested in?'")
print(data['14. Which of these careers are you interested in?'].value_counts())
print("\nUnique values in '20. Regarding employment status, are you currently....'")
# Out:
# Unique values in '1. What is your biggest reason for learning to code?'
# 1. What is your biggest reason for learning to code?
# To change careers                      3
# To succeed in current career           2
# As a hobby                             2
# To start your first career             2
# To start a business or to freelance    1
# Name: count, dtype: int64
#
# Unique values in '14. Which of these careers are you interested in?'
# 14. Which of these careers are you interested in?
# Full-Stack Web Developer    5
# DevOps / SysAdmin           1
# Front-End Web Developer     1
# Information Security        1
# Product Manager             1
# Mobile Developer            1
# Name: count, dtype: int64
#
# Unique values in '20. Regarding employment status, are you currently....'

# %%
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
print(f"Numerical columns: {numerical_cols}")
corr = data[numerical_cols].corr()
print("\nCorrelation matrix:")
print(corr)
# Out:
# Numerical columns: Index(['7. About how many hours do you spend learning each week?',
#        '8. About how many months have you been programming?',
#        '9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?',
#        '23. How old are you?',
#        '36. How many children do you have? By children, we mean any biological, step, or adopted children.',
#        '39. How much debt does your household have? [Medical Loans]',
#        '39. How much debt does your household have? [Other]',
#        '41. Before you got your last job, how many months did you spend looking for a job?',
#        '42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?  ',
#        '43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have? '],
#       dtype='object')
#
# Correlation matrix:
#                                                     7. About how many hours do you spend learning each week?  \
# 7. About how many hours do you spend learning e...                                           1.000000
# 8. About how many months have you been programm...                                          -0.177058
# 9. Aside from university tuition, about how muc...                                          -0.514723
# 23. How old are you?                                                                         0.290364
# 36. How many children do you have? By children,...                                           0.599630
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.707216
# 42. If you are working, thinking about the next...                                          -0.243554
# 43. If you are working, how easy would it be fo...                                           0.353099
#
#                                                     8. About how many months have you been programming?  \
# 7. About how many hours do you spend learning e...                                          -0.177058
# 8. About how many months have you been programm...                                           1.000000
# 9. Aside from university tuition, about how muc...                                           0.091032
# 23. How old are you?                                                                        -0.190475
# 36. How many children do you have? By children,...                                          -0.413890
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.005557
# 42. If you are working, thinking about the next...                                          -0.438810
# 43. If you are working, how easy would it be fo...                                           0.532988
#
#                                                     9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?  \
# 7. About how many hours do you spend learning e...                                          -0.514723
# 8. About how many months have you been programm...                                           0.091032
# 9. Aside from university tuition, about how muc...                                           1.000000
# 23. How old are you?                                                                        -0.135376
# 36. How many children do you have? By children,...                                          -0.259706
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.151914
# 42. If you are working, thinking about the next...                                          -0.232763
# 43. If you are working, how easy would it be fo...                                           0.098416
#
#                                                     23. How old are you?  \
# 7. About how many hours do you spend learning e...              0.290364
# 8. About how many months have you been programm...             -0.190475
# 9. Aside from university tuition, about how muc...             -0.135376
# 23. How old are you?                                            1.000000
# 36. How many children do you have? By children,...              0.857170
# 39. How much debt does your household have? [Me...                   NaN
# 39. How much debt does your household have? [Ot...                   NaN
# 41. Before you got your last job, how many mont...             -0.656250
# 42. If you are working, thinking about the next...              0.211582
# 43. If you are working, how easy would it be fo...             -0.333102
#
#                                                     36. How many children do you have? By children, we mean any biological, step, or adopted children.  \
# 7. About how many hours do you spend learning e...                                           0.599630
# 8. About how many months have you been programm...                                          -0.413890
# 9. Aside from university tuition, about how muc...                                          -0.259706
# 23. How old are you?                                                                         0.857170
# 36. How many children do you have? By children,...                                           1.000000
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.392031
# 42. If you are working, thinking about the next...                                           0.055880
# 43. If you are working, how easy would it be fo...                                          -0.191282
#
#                                                     39. How much debt does your household have? [Medical Loans]  \
# 7. About how many hours do you spend learning e...                                                NaN
# 8. About how many months have you been programm...                                                NaN
# 9. Aside from university tuition, about how muc...                                                NaN
# 23. How old are you?                                                                              NaN
# 36. How many children do you have? By children,...                                                NaN
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                                NaN
# 42. If you are working, thinking about the next...                                                NaN
# 43. If you are working, how easy would it be fo...                                                NaN
#
#                                                     39. How much debt does your household have? [Other]  \
# 7. About how many hours do you spend learning e...                                                NaN
# 8. About how many months have you been programm...                                                NaN
# 9. Aside from university tuition, about how muc...                                                NaN
# 23. How old are you?                                                                              NaN
# 36. How many children do you have? By children,...                                                NaN
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                                NaN
# 42. If you are working, thinking about the next...                                                NaN
# 43. If you are working, how easy would it be fo...                                                NaN
#
#                                                     41. Before you got your last job, how many months did you spend looking for a job?  \
# 7. About how many hours do you spend learning e...                                           0.707216
# 8. About how many months have you been programm...                                           0.005557
# 9. Aside from university tuition, about how muc...                                          -0.151914
# 23. How old are you?                                                                        -0.656250
# 36. How many children do you have? By children,...                                          -0.392031
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           1.000000
# 42. If you are working, thinking about the next...                                          -0.133631
# 43. If you are working, how easy would it be fo...                                           0.112598
#
#                                                     42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?    \
# 7. About how many hours do you spend learning e...                                          -0.243554
# 8. About how many months have you been programm...                                          -0.438810
# 9. Aside from university tuition, about how muc...                                          -0.232763
# 23. How old are you?                                                                         0.211582
# 36. How many children do you have? By children,...                                           0.055880
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.133631
# 42. If you are working, thinking about the next...                                           1.000000
# 43. If you are working, how easy would it be fo...                                          -0.541675
#
#                                                     43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have?
# 7. About how many hours do you spend learning e...                                           0.353099
# 8. About how many months have you been programm...                                           0.532988
# 9. Aside from university tuition, about how muc...                                           0.098416
# 23. How old are you?                                                                        -0.333102
# 36. How many children do you have? By children,...                                          -0.191282
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.112598
# 42. If you are working, thinking about the next...                                          -0.541675
# 43. If you are working, how easy would it be fo...                                           1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
print(f"Numerical columns: {numerical_cols}")

corr = data[numerical_cols].corr()
print("\nCorrelation matrix:")
print(corr)

corr = corr.fillna(0)

short_names = {
    '7. About how many hours do you spend learning each week?': 'Hours Learning',
    '8. About how many months have you been programming?': 'Months Programming',
    '9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?': 'Money Spent Learning',
    '23. How old are you?': 'Age',
    '36. How many children do you have? By children, we mean any biological, step, or adopted children.': 'Children',
    '39. How much debt does your household have? [Medical Loans]': 'Medical Debt',
    '39. How much debt does your household have? [Other]': 'Other Debt',
    '41. Before you got your last job, how many months did you spend looking for a job?': 'Months Job Hunting',
    '42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?': 'Job Loss Likelihood',
    '43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have?': 'Job Finding Ease'
}
corr.rename(columns=short_names, index=short_names, inplace=True)

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# Numerical columns: Index(['7. About how many hours do you spend learning each week?',
#        '8. About how many months have you been programming?',
#        '9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?',
#        '23. How old are you?',
#        '36. How many children do you have? By children, we mean any biological, step, or adopted children.',
#        '39. How much debt does your household have? [Medical Loans]',
#        '39. How much debt does your household have? [Other]',
#        '41. Before you got your last job, how many months did you spend looking for a job?',
#        '42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?  ',
#        '43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have? '],
#       dtype='object')
#
# Correlation matrix:
#                                                     7. About how many hours do you spend learning each week?  \
# 7. About how many hours do you spend learning e...                                           1.000000
# 8. About how many months have you been programm...                                          -0.177058
# 9. Aside from university tuition, about how muc...                                          -0.514723
# 23. How old are you?                                                                         0.290364
# 36. How many children do you have? By children,...                                           0.599630
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.707216
# 42. If you are working, thinking about the next...                                          -0.243554
# 43. If you are working, how easy would it be fo...                                           0.353099
#
#                                                     8. About how many months have you been programming?  \
# 7. About how many hours do you spend learning e...                                          -0.177058
# 8. About how many months have you been programm...                                           1.000000
# 9. Aside from university tuition, about how muc...                                           0.091032
# 23. How old are you?                                                                        -0.190475
# 36. How many children do you have? By children,...                                          -0.413890
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.005557
# 42. If you are working, thinking about the next...                                          -0.438810
# 43. If you are working, how easy would it be fo...                                           0.532988
#
#                                                     9. Aside from university tuition, about how much money have you spent on learning to code so far (in US Dollars)?  \
# 7. About how many hours do you spend learning e...                                          -0.514723
# 8. About how many months have you been programm...                                           0.091032
# 9. Aside from university tuition, about how muc...                                           1.000000
# 23. How old are you?                                                                        -0.135376
# 36. How many children do you have? By children,...                                          -0.259706
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.151914
# 42. If you are working, thinking about the next...                                          -0.232763
# 43. If you are working, how easy would it be fo...                                           0.098416
#
#                                                     23. How old are you?  \
# 7. About how many hours do you spend learning e...              0.290364
# 8. About how many months have you been programm...             -0.190475
# 9. Aside from university tuition, about how muc...             -0.135376
# 23. How old are you?                                            1.000000
# 36. How many children do you have? By children,...              0.857170
# 39. How much debt does your household have? [Me...                   NaN
# 39. How much debt does your household have? [Ot...                   NaN
# 41. Before you got your last job, how many mont...             -0.656250
# 42. If you are working, thinking about the next...              0.211582
# 43. If you are working, how easy would it be fo...             -0.333102
#
#                                                     36. How many children do you have? By children, we mean any biological, step, or adopted children.  \
# 7. About how many hours do you spend learning e...                                           0.599630
# 8. About how many months have you been programm...                                          -0.413890
# 9. Aside from university tuition, about how muc...                                          -0.259706
# 23. How old are you?                                                                         0.857170
# 36. How many children do you have? By children,...                                           1.000000
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.392031
# 42. If you are working, thinking about the next...                                           0.055880
# 43. If you are working, how easy would it be fo...                                          -0.191282
#
#                                                     39. How much debt does your household have? [Medical Loans]  \
# 7. About how many hours do you spend learning e...                                                NaN
# 8. About how many months have you been programm...                                                NaN
# 9. Aside from university tuition, about how muc...                                                NaN
# 23. How old are you?                                                                              NaN
# 36. How many children do you have? By children,...                                                NaN
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                                NaN
# 42. If you are working, thinking about the next...                                                NaN
# 43. If you are working, how easy would it be fo...                                                NaN
#
#                                                     39. How much debt does your household have? [Other]  \
# 7. About how many hours do you spend learning e...                                                NaN
# 8. About how many months have you been programm...                                                NaN
# 9. Aside from university tuition, about how muc...                                                NaN
# 23. How old are you?                                                                              NaN
# 36. How many children do you have? By children,...                                                NaN
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                                NaN
# 42. If you are working, thinking about the next...                                                NaN
# 43. If you are working, how easy would it be fo...                                                NaN
#
#                                                     41. Before you got your last job, how many months did you spend looking for a job?  \
# 7. About how many hours do you spend learning e...                                           0.707216
# 8. About how many months have you been programm...                                           0.005557
# 9. Aside from university tuition, about how muc...                                          -0.151914
# 23. How old are you?                                                                        -0.656250
# 36. How many children do you have? By children,...                                          -0.392031
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           1.000000
# 42. If you are working, thinking about the next...                                          -0.133631
# 43. If you are working, how easy would it be fo...                                           0.112598
#
#                                                     42. If you are working, thinking about the next 12 months, how likely do you think it is that you will lose your job or be laid off?    \
# 7. About how many hours do you spend learning e...                                          -0.243554
# 8. About how many months have you been programm...                                          -0.438810
# 9. Aside from university tuition, about how muc...                                          -0.232763
# 23. How old are you?                                                                         0.211582
# 36. How many children do you have? By children,...                                           0.055880
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                          -0.133631
# 42. If you are working, thinking about the next...                                           1.000000
# 43. If you are working, how easy would it be fo...                                          -0.541675
#
#                                                     43. If you are working, how easy would it be for you to find a job with another employer with approximately the same income and fringe benefits you now have?
# 7. About how many hours do you spend learning e...                                           0.353099
# 8. About how many months have you been programm...                                           0.532988
# 9. Aside from university tuition, about how muc...                                           0.098416
# 23. How old are you?                                                                        -0.333102
# 36. How many children do you have? By children,...                                          -0.191282
# 39. How much debt does your household have? [Me...                                                NaN
# 39. How much debt does your household have? [Ot...                                                NaN
# 41. Before you got your last job, how many mont...                                           0.112598
# 42. If you are working, thinking about the next...                                          -0.541675
# 43. If you are working, how easy would it be fo...                                           1.000000

# %%
num_numerical_cols = len(numerical_cols)
print(f"Number of numerical columns: {num_numerical_cols}")
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 4, i + 1)
    data[col].hist(bins=20)
    plt.title(col)
    plt.tight_layout()
plt.show()
# Out:
# Number of numerical columns: 10
# C:\Users\theoldregime\AppData\Local\Temp\ipykernel_32516\3207211705.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 7
#       5 plt.figure(figsize=(12, 6))
#       6 for i, col in enumerate(numerical_cols):
# ----> 7     plt.subplot(2, 4, i + 1)
#       8     data[col].hist(bins=20)
#       9     plt.title(col)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:600, in SubplotSpec._from_subplot_args(figure, args)
#     598 else:
#     599     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 600         raise ValueError(
#     601             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     602             f"not {num!r}"
#     603         )
#     604     i = j = num
#     605 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 8, not 9

# %%
#2. Implement cluster analysis and understand the characteristics of new coders in each cluster.

# %%
#3. Implement classification and build machine learning models for predicting whether a developer is in high income based on developers’ information.
